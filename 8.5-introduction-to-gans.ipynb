# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %% [markdown]
# # Introduction to generative adversarial networks

# %% [markdown]
# ## A schematic GAN implementation
#
# Our specific implementation will be a deep convolutional GAN, or DCGAN: a GAN where the
# generator and discriminator are deep convnets. In particular, it leverages a `Conv2DTranspose` layer for image upsampling in the generator.

# %% [markdown]
# ## The generator
#
#
# First, we develop a `generator` model, which turns a vector (from the latent space -- during training it will sampled at random) into a
# candidate image. One of the many issues that commonly arise with GANs is that the generator gets stuck with generated images that look like
# noise. A possible solution is to use dropout on both the discriminator and generator.

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## The discriminator
#
#
# Then, we develop a `discriminator` model, that takes as input a candidate image (real or synthetic) and classifies it into one of two
# classes, either "generated image" or "real image that comes from the training set".

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## The adversarial network
#
# Finally, we setup the GAN, which chains the generator and the discriminator. This is the model that, when trained, will move the generator
# in a direction that improves its ability to fool the discriminator. This model turns latent space points into a classification decision,
# "fake" or "real", and it is meant to be trained with labels that are always "these are real images". So training `gan` will updates the
# weights of `generator` in a way that makes `discriminator` more likely to predict "real" when looking at fake images. Very importantly, we
# set the discriminator to be frozen during training (non-trainable): its weights will not be updated when training `gan`. If the
# discriminator weights could be updated during this process, then we would be training the discriminator to always predict "real", which is
# not what we want!

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ## How to train your DCGAN
#
# Now we can start training. To recapitulate, this is schematically what the training loop looks like:
#
# ```
# for each epoch:
#     * Draw random points in the latent space (random noise).
#     * Generate images with `generator` using this random noise.
#     * Mix the generated images with real ones.
#     * Train `discriminator` using these mixed images, with corresponding targets, either "real" (for the real images) or "fake" (for the generated images).
#     * Draw new random points in the latent space.
#     * Train `gan` using these random vectors, with targets that all say "these are real images". This will update the weights of the generator (only, since discriminator is frozen inside `gan`) to move them towards getting the discriminator to predict "these are real images" for generated images, i.e. this trains the generator to fool the discriminator.
# ```
#
# Let's implement it:

# %%
# !mkdir gan_images

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = './gan_images/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 0: 5.344539
# adversarial loss at step 0: 11.075809
# discriminator loss at step 100: 0.67187244
# adversarial loss at step 100: 0.8263849
# discriminator loss at step 200: 0.6857205
# adversarial loss at step 200: 0.8983595
# discriminator loss at step 300: 0.71651834
# adversarial loss at step 300: 0.7219824
# discriminator loss at step 400: 0.71651256
# adversarial loss at step 400: 0.76954263
# discriminator loss at step 500: 0.7036786
# adversarial loss at step 500: 0.72578335
# discriminator loss at step 600: 0.6884958
# adversarial loss at step 600: 0.7309221
# discriminator loss at step 700: 0.6966416
# adversarial loss at step 700: 0.79263175
# discriminator loss at step 800: 0.698177
# adversarial loss at step 800: 0.73316133
# discriminator loss at step 900: 0.6932479
# adversarial loss at step 900: 0.7318033
# discriminator loss at step 1000: 0.692151
# adversarial loss at step 1000: 0.7269789
# discriminator loss at step 1100: 0.69022954
# adversarial loss at step 1100: 0.75265867
# discriminator loss at step 1200: 0.68421096
# adversarial loss at step 1200: 0.757131
# discriminator loss at step 1300: 0.68382895
# adversarial loss at step 1300: 0.73878866
# discriminator loss at step 1400: 0.70630616
# adversarial loss at step 1400: 0.7413405
# discriminator loss at step 1500: 0.69084835
# adversarial loss at step 1500: 0.7553672
# discriminator loss at step 1600: 0.6878127
# adversarial loss at step 1600: 0.74096787
# discriminator loss at step 1700: 0.6873649
# adversarial loss at step 1700: 0.75934404
# discriminator loss at step 1800: 0.6829959
# adversarial loss at step 1800: 0.6950697
# discriminator loss at step 1900: 0.6963553
# adversarial loss at step 1900: 0.74437076
# discriminator loss at step 2000: 0.695424
# adversarial loss at step 2000: 0.7415063
# discriminator loss at step 2100: 0.69067585
# adversarial loss at step 2100: 0.7663995
# discriminator loss at step 2200: 0.6842528
# adversarial loss at step 2200: 0.7362938
# discriminator loss at step 2300: 0.6916724
# adversarial loss at step 2300: 0.73559463
# discriminator loss at step 2400: 0.69347864
# adversarial loss at step 2400: 0.7675869
# discriminator loss at step 2500: 0.9232708
# adversarial loss at step 2500: 0.7385482
# discriminator loss at step 2600: 0.68973255
# adversarial loss at step 2600: 0.7114302
# discriminator loss at step 2700: 0.68036973
# adversarial loss at step 2700: 0.81219256
# discriminator loss at step 2800: 0.7308883
# adversarial loss at step 2800: 0.76456225
# discriminator loss at step 2900: 0.6935934
# adversarial loss at step 2900: 0.73358834
# discriminator loss at step 3000: 0.6733338
# adversarial loss at step 3000: 0.79689276
# discriminator loss at step 3100: 0.70594203
# adversarial loss at step 3100: 0.76126516
# discriminator loss at step 3200: 0.69146013
# adversarial loss at step 3200: 0.7437196
# discriminator loss at step 3300: 0.72658575
# adversarial loss at step 3300: 0.7750204
# discriminator loss at step 3400: 0.6896749
# adversarial loss at step 3400: 0.74438524
# discriminator loss at step 3500: 0.69760466
# adversarial loss at step 3500: 0.73362035
# discriminator loss at step 3600: 0.70421064
# adversarial loss at step 3600: 0.78534406
# discriminator loss at step 3700: 0.69107515
# adversarial loss at step 3700: 0.7337492
# discriminator loss at step 3800: 0.69762766
# adversarial loss at step 3800: 0.7500846
# discriminator loss at step 3900: 0.69560736
# adversarial loss at step 3900: 0.7529453
# discriminator loss at step 4000: 0.684686
# adversarial loss at step 4000: 0.7170495
# discriminator loss at step 4100: 0.6868473
# adversarial loss at step 4100: 0.7212083
# discriminator loss at step 4200: 0.6956171
# adversarial loss at step 4200: 0.71979535
# discriminator loss at step 4300: 0.7128993
# adversarial loss at step 4300: 0.7698306
# discriminator loss at step 4400: 0.7007486
# adversarial loss at step 4400: 0.6942121
# discriminator loss at step 4500: 0.69449216
# adversarial loss at step 4500: 0.7398895
# discriminator loss at step 4600: 0.6905739
# adversarial loss at step 4600: 0.7513241
# discriminator loss at step 4700: 0.71728796
# adversarial loss at step 4700: 0.824461
# discriminator loss at step 4800: 0.68698525
# adversarial loss at step 4800: 0.7458884
# discriminator loss at step 4900: 0.7008611
# adversarial loss at step 4900: 0.754927
# discriminator loss at step 5000: 0.6916737
# adversarial loss at step 5000: 0.7519258
# discriminator loss at step 5100: 0.6934303
# adversarial loss at step 5100: 0.74573636
# discriminator loss at step 5200: 0.68349695
# adversarial loss at step 5200: 0.7291945
# discriminator loss at step 5300: 0.6877559
# adversarial loss at step 5300: 0.7320837
# discriminator loss at step 5400: 0.6957005
# adversarial loss at step 5400: 0.7419623
# discriminator loss at step 5500: 0.6966891
# adversarial loss at step 5500: 0.7770585
# discriminator loss at step 5600: 0.69369966
# adversarial loss at step 5600: 0.78011996
# discriminator loss at step 5700: 0.69145525
# adversarial loss at step 5700: 0.7819163
# discriminator loss at step 5800: 0.764007
# adversarial loss at step 5800: 0.64576006
# discriminator loss at step 5900: 0.71508086
# adversarial loss at step 5900: 0.5454636
# discriminator loss at step 6000: 0.6801578
# adversarial loss at step 6000: 0.78655946
# discriminator loss at step 6100: 0.6646269
# adversarial loss at step 6100: 0.66066444
# discriminator loss at step 6200: 0.7023277
# adversarial loss at step 6200: 0.7965859
# discriminator loss at step 6300: 0.7180141
# adversarial loss at step 6300: 0.9739664
# discriminator loss at step 6400: 0.7169486
# adversarial loss at step 6400: 0.80550134
# discriminator loss at step 6500: 0.68991095
# adversarial loss at step 6500: 1.8814476
# discriminator loss at step 6600: 0.6726016
# adversarial loss at step 6600: 0.7874711
# discriminator loss at step 6700: 0.6956535
# adversarial loss at step 6700: 0.77173644
# discriminator loss at step 6800: 0.6565093
# adversarial loss at step 6800: 0.7788962
# discriminator loss at step 6900: 0.80115634
# adversarial loss at step 6900: 0.66395885
# discriminator loss at step 7000: 0.6973575
# adversarial loss at step 7000: 0.8239439
# discriminator loss at step 7100: 0.7335628
# adversarial loss at step 7100: 1.3375717
# discriminator loss at step 7200: 0.72369295
# adversarial loss at step 7200: 0.80735934
# discriminator loss at step 7300: 0.74705136
# adversarial loss at step 7300: 0.8225285
# discriminator loss at step 7400: 0.67392266
# adversarial loss at step 7400: 0.686086
# discriminator loss at step 7500: 0.66547793
# adversarial loss at step 7500: 0.7659314
# discriminator loss at step 7600: 0.6815418
# adversarial loss at step 7600: 0.79623747
# discriminator loss at step 7700: 0.5784135
# adversarial loss at step 7700: 2.3666973
# discriminator loss at step 7800: 0.6833227
# adversarial loss at step 7800: 0.86477375
# discriminator loss at step 7900: 0.6928711
# adversarial loss at step 7900: 0.8181368
# discriminator loss at step 8000: 0.6731826
# adversarial loss at step 8000: 0.8510645
# discriminator loss at step 8100: 0.69737196
# adversarial loss at step 8100: 0.94527847
# discriminator loss at step 8200: 0.69985336
# adversarial loss at step 8200: 0.7896935
# discriminator loss at step 8300: 0.7053083
# adversarial loss at step 8300: 0.6905775
# discriminator loss at step 8400: 0.72254133
# adversarial loss at step 8400: 0.6606916
# discriminator loss at step 8500: 0.6751225
# adversarial loss at step 8500: 0.71950614
# discriminator loss at step 8600: 0.6799415
# adversarial loss at step 8600: 0.97914046
# discriminator loss at step 8700: 0.7123731
# adversarial loss at step 8700: 0.6075696
# discriminator loss at step 8800: 0.6765385
# adversarial loss at step 8800: 0.79564315
# discriminator loss at step 8900: 0.68790233
# adversarial loss at step 8900: 0.63587904
# discriminator loss at step 9000: 0.68640745
# adversarial loss at step 9000: 0.7801808
# discriminator loss at step 9100: 0.6826177
# adversarial loss at step 9100: 0.7604703
# discriminator loss at step 9200: 0.7695295
# adversarial loss at step 9200: 0.78036344
# discriminator loss at step 9300: 0.6881744
# adversarial loss at step 9300: 0.83612806
# discriminator loss at step 9400: 0.7081591
# adversarial loss at step 9400: 0.6770114
# discriminator loss at step 9500: 0.71258765
# adversarial loss at step 9500: 1.1359415
# discriminator loss at step 9600: 0.68197
# adversarial loss at step 9600: 0.7480522
# discriminator loss at step 9700: 0.64472723
# adversarial loss at step 9700: 0.7923687
# discriminator loss at step 9800: 0.64987934
# adversarial loss at step 9800: 0.88110656
# discriminator loss at step 9900: 0.73363936
# adversarial loss at step 9900: 0.75507224

# %% [markdown]
# Let's display a few of our fake images:

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
